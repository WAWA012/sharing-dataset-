# %% [markdown]
# **Proyek Analisis Data: Bike Sharing Dataset**
# - **Nama:** Jihan Kusumawardhani
# - **Email:** jihankusumawwardhani@gmail.com
# - **ID Dicoding:** https://www.dicoding.com/users/jihankusumawardhani

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# 1. Bagaimana perbedaan antara pengguna yang menggunakan layanan bike sharing secara kasual tanpa registrasi dengan mereka yang telah mendaftar sebagai anggota tetap dalam sistem tersebut?
# 2. Pada jam berapa dalam sehari tingkat penggunaan layanan bike sharing mencapai puncak tertinggi, dan pada jam berapa penggunaan tersebut berada pada titik terendah?
# 3. Bagaimana perbedaan dalam pola penggunaan layanan bike sharing ketika dihadapkan pada empat kondisi cuaca yang berbeda, dan sejauh mana faktor cuaca memengaruhi tingkat penggunaannya?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print('Import Successful')
# Out:
# Import Successful

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data
#
# *   Gathering Day Data

# %%
day_df = pd.read_csv("/content/day.csv")
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# *   Gathering Hour Data

# %%
hour_df = pd.read_csv("/content/hour.csv")
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Assessing Data day_df
# *   Melakukan verifikasi terhadap jenis data yang digunakan serta mengidentifikasi adanya nilai yang tidak akurat atau tidak sesuai dalam dataset *day_df* guna memastikan kualitas dan keandalan data sebelum dilakukan analisis lebih lanjut

# %%
day_df.info()
day_df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB
#            instant      dteday      season          yr        mnth  \
# ...

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
day_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Insight
#
# Dalam proses pembersihan data pada dataset *day_df*, dilakukan beberapa tahap transformasi untuk memastikan kualitas dan keterbacaan data.
#
# 1. **Pemeriksaan Kualitas Data:** Tidak ditemukan adanya *missing values*, *duplicated values*, maupun *inaccurate values* pada dataset *day_df*, sehingga tidak diperlukan langkah tambahan untuk menangani permasalahan tersebut.
#
# 2. **Penghapusan Kolom yang Tidak Relevan:** Variabel *temp*, *atemp*, *hum*, dan *windspeed* dianggap tidak memiliki kontribusi signifikan dalam menjawab pertanyaan analisis yang telah dirumuskan. Oleh karena itu, kolom-kolom tersebut dihapus selama tahap *data cleaning* guna meningkatkan efisiensi analisis.
#
# 3. **Penyesuaian Nama Kolom:** Beberapa kolom seperti *instant*, *dteday*, *yr*, *mnth*, *weathersit*, dan *cnt* memiliki nama yang kurang deskriptif dan dapat menyebabkan kebingungan dalam interpretasi data. Oleh karena itu, dilakukan proses *renaming* terhadap kolom-kolom tersebut agar lebih mudah dipahami.
#
# 4. **Transformasi Tipe Data:** Kolom *season*, *year*, *month*, *holiday*, *weekday*, *workingday*, dan *weather* masih dalam bentuk tipe data numerik (*integer*), sehingga perlu dikonversi menjadi tipe data kategorikal agar lebih sesuai dengan karakteristik datanya dan mempermudah analisis lebih lanjut.
#
# 5. **Standarisasi Nilai dalam Variabel Kategorikal:** Nilai yang terdapat dalam kolom *season*, *year*, *holiday*, *weekday*, *workingday*, dan *weather* masih menggunakan format yang kurang intuitif dan sulit dipahami. Oleh karena itu, dilakukan penyesuaian nilai dalam kolom-kolom tersebut agar lebih representatif.
#
# 6. **Konversi Format Tanggal:** Kolom *dteday* saat ini masih dalam bentuk objek (*string*), sehingga perlu dikonversi ke dalam format *datetime* untuk mendukung analisis berbasis waktu dengan lebih optimal.

# %% [markdown]
# ### Assessing Data hour_df
# *   Melakukan verifikasi terhadap jenis data yang digunakan serta mengidentifikasi adanya nilai yang tidak akurat atau tidak sesuai dalam dataset *hour_df* guna memastikan kualitas dan keandalan data sebelum dilakukan analisis lebih lanjut.

# %%
hour_df.info()
hour_df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB
# ...

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
hour_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Insight
#
# Dalam proses pembersihan data pada dataset hour_df, dilakukan beberapa tahap transformasi dan penyesuaian sebagai berikut:
#
# 1. Pemeriksaan Kualitas Data
# Berdasarkan hasil analisis awal, tidak ditemukan adanya missing value (nilai yang hilang), duplicated value (nilai duplikat), maupun inaccurate value (nilai yang tidak akurat) dalam dataset hour_df, sehingga tidak diperlukan proses imputasi atau deduplikasi data.
#
# 2. Penghapusan Kolom yang Tidak Relevan
# Beberapa atribut, seperti temp, atemp, hum, dan windspeed, tidak memiliki kontribusi yang signifikan dalam menjawab pertanyaan analisis yang akan dilakukan. Oleh karena itu, atribut-atribut tersebut akan dihapus dalam tahap pembersihan data untuk mengurangi kompleksitas dataset.
#
# 3. Penyesuaian Nama Kolom
# Beberapa kolom dalam dataset, seperti instant, dteday, yr, mnth, hr, weathersit, dan cnt, memiliki nama yang kurang deskriptif atau sulit dipahami. Oleh karena itu, nama-nama kolom ini akan diperbarui agar lebih jelas dan sesuai dengan standar penamaan yang lebih informatif.
#
# 4. Transformasi Tipe Data
#
# *   Kolom season, year, month, hour, holiday, weekday, workingday, dan weather saat ini masih dalam format numerik (integer), padahal nilai-nilai tersebut merepresentasikan kategori tertentu. Oleh karena itu, tipe data untuk kolom-kolom ini akan dikonversi menjadi kategorikal agar lebih sesuai dengan karakteristik data.
#
# * Selain itu, nilai yang terdapat dalam kolom season, year, hour, holiday, weekday, workingday, dan weather masih dalam format yang kurang intuitif. Oleh karena itu, akan dilakukan proses penyesuaian nilai agar lebih mudah dipahami dan digunakan dalam analisis.
#
# * Kolom dteday yang masih berbentuk string atau objek akan dikonversi menjadi tipe data datetime untuk memungkinkan pemrosesan waktu yang lebih efisien.

# %% [markdown]
# ### Cleaning day-df data

# %%
day_df.drop(columns=['temp', 'atemp', 'hum', 'windspeed'], inplace=True)
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit  casual  registered   cnt
# 0           2     331         654   985
# 1           2     131         670   801
# 2           1     120        1229  1349
# 3           1     108        1454  1562
# 4           1      82        1518  1600

# %% [markdown]
# *  Melakukan perubahan nama pada beberapa kolom dalam dataset, yaitu instant, dteday, yr, mnth, weathersit, dan cnt, guna meningkatkan keterbacaan serta mempermudah interpretasi data dalam proses analisis yang lebih sistematis dan komprehensif.

# %%
day_df.rename(columns={'instant':'rec_id', 'dteday':'dateday', 'yr':'year', 'mnth':'month', 'weathersit':'weather', 'cnt':'total'}, inplace=True)
day_df.head()
# Out:
#    rec_id     dateday  season  year  month  holiday  weekday  workingday  \
# 0       1  2011-01-01       1     0      1        0        6           0
# 1       2  2011-01-02       1     0      1        0        0           0
# 2       3  2011-01-03       1     0      1        0        1           1
# 3       4  2011-01-04       1     0      1        0        2           1
# 4       5  2011-01-05       1     0      1        0        3           1
#
#    weather  casual  registered  total
# 0        2     331         654    985
# 1        2     131         670    801
# 2        1     120        1229   1349
# 3        1     108        1454   1562
# 4        1      82        1518   1600

# %% [markdown]
# * Tipe data pada kolom *season*, *year*, *month*, *holiday*, *weekday*, *workingday*, dan *weathersit* dikonversi menjadi tipe data kategorikal untuk mencerminkan sifat diskrit dari variabel-variabel tersebut. Langkah ini bertujuan untuk meningkatkan keakuratan analisis data serta memastikan bahwa setiap nilai dalam kolom-kolom tersebut diperlakukan sebagai kategori yang terpisah, bukan sebagai variabel numerik yang memiliki hubungan ordinal atau kontinu.

# %%
for col in ['season', 'year', 'month', 'holiday', 'weekday', 'workingday', 'weather']:
    day_df[col] = day_df[col].astype('category')

day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rec_id      731 non-null    int64
#  1   dateday     731 non-null    object
#  2   season      731 non-null    category
#  3   year        731 non-null    category
#  4   month       731 non-null    category
#  5   holiday     731 non-null    category
#  6   weekday     731 non-null    category
#  7   workingday  731 non-null    category
#  8   weather     731 non-null    category
#  9   casual      731 non-null    int64
#  10  registered  731 non-null    int64
#  11  total       731 non-null    int64
# dtypes: category(7), int64(4), object(1)
# memory usage: 35.1+ KB

# %% [markdown]
# * Melakukan modifikasi terhadap nilai yang terdapat dalam kolom *season* guna memastikan kesesuaiannya dengan konteks data yang diolah, sehingga dapat meningkatkan akurasi dan relevansi dalam analisis yang dilakukan.

# %%
day_df['season'] = day_df['season'].replace({
    1:'springer',
    2:'summer',
    3:'fall',
    4:'winter'
})

day_df.head()
# Out:
# <ipython-input-14-a4d1ef00bb94>:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   day_df['season'] = day_df['season'].replace({
#    rec_id     dateday    season year month holiday weekday workingday weather  \
# 0       1  2011-01-01  springer    0     1       0       6          0       2
# 1       2  2011-01-02  springer    0     1       0       0          0       2
# 2       3  2011-01-03  springer    0     1       0       1          1       1
# 3       4  2011-01-04  springer    0     1       0       2          1       1
# 4       5  2011-01-05  springer    0     1       0       3          1       1
#
#    casual  registered  total
# 0     331         654    985
# 1     131         670    801
# 2     120        1229   1349
# 3     108        1454   1562
# ...

# %% [markdown]
# * Melakukan penyesuaian terhadap nilai pada kolom *year* sehingga lebih selaras dan sesuai dengan konteks serta standar yang diharapkan.

# %%
day_df['year'] = day_df['year'].replace({
    0:2011,
    1:2012
})

day_df.head()
# Out:
# <ipython-input-15-ca7865e34ff3>:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   day_df['year'] = day_df['year'].replace({
#    rec_id     dateday    season  year month holiday weekday workingday  \
# 0       1  2011-01-01  springer  2011     1       0       6          0
# 1       2  2011-01-02  springer  2011     1       0       0          0
# 2       3  2011-01-03  springer  2011     1       0       1          1
# 3       4  2011-01-04  springer  2011     1       0       2          1
# 4       5  2011-01-05  springer  2011     1       0       3          1
#
#   weather  casual  registered  total
# 0       2     331         654    985
# 1       2     131         670    801
# 2       1     120        1229   1349
# 3       1     108        1454   1562
# ...

# %% [markdown]
# * Melakukan modifikasi terhadap nilai yang terdapat dalam kolom *holiday* guna memastikan bahwa data yang tersimpan lebih relevan, konsisten, dan sesuai dengan konteks analisis yang diinginkan.

# %%
day_df['holiday'] = day_df['holiday'].replace({
    0:'Not Holiday',
    1:'Holiday'
})

day_df.head()
# Out:
# <ipython-input-16-0700a011e83d>:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   day_df['holiday'] = day_df['holiday'].replace({
#    rec_id     dateday    season  year month      holiday weekday workingday  \
# 0       1  2011-01-01  springer  2011     1  Not Holiday       6          0
# 1       2  2011-01-02  springer  2011     1  Not Holiday       0          0
# 2       3  2011-01-03  springer  2011     1  Not Holiday       1          1
# 3       4  2011-01-04  springer  2011     1  Not Holiday       2          1
# 4       5  2011-01-05  springer  2011     1  Not Holiday       3          1
#
#   weather  casual  registered  total
# 0       2     331         654    985
# 1       2     131         670    801
# 2       1     120        1229   1349
# ...

# %% [markdown]
# * Melakukan penyesuaian terhadap nilai yang terdapat dalam kolom *weekday* guna memastikan kesesuaian yang lebih optimal dengan konteks analisis atau kebutuhan spesifik dalam pengolahan data.

# %%
day_df['weekday'] = day_df['weekday'].replace({
    0:'Sunday',
    1:'Monday',
    2:'Tuesday',
    3:'Wednesday',
    4:'Thursday',
    5:'Friday',
    6:'Saturday'
})

day_df.head()
# Out:
# <ipython-input-17-9b2052fba725>:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   day_df['weekday'] = day_df['weekday'].replace({
#    rec_id     dateday    season  year month      holiday    weekday  \
# 0       1  2011-01-01  springer  2011     1  Not Holiday   Saturday
# 1       2  2011-01-02  springer  2011     1  Not Holiday     Sunday
# 2       3  2011-01-03  springer  2011     1  Not Holiday     Monday
# 3       4  2011-01-04  springer  2011     1  Not Holiday    Tuesday
# 4       5  2011-01-05  springer  2011     1  Not Holiday  Wednesday
#
#   workingday weather  casual  registered  total
# 0          0       2     331         654    985
# 1          0       2     131         670    801
# 2          1       1     120        1229   1349
# ...

# %% [markdown]
# * Melakukan penyesuaian nilai pada kolom *workingday* guna memastikan kesesuaian data dengan konteks analisis yang diinginkan, sehingga dapat meningkatkan validitas serta relevansi informasi yang diperoleh.

# %%
day_df['workingday'] = day_df['workingday'].replace({
    0:'Offday',
    1:'Workday'
})

day_df.head()
# Out:
# <ipython-input-18-d0063fcaf239>:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   day_df['workingday'] = day_df['workingday'].replace({
#    rec_id     dateday    season  year month      holiday    weekday  \
# 0       1  2011-01-01  springer  2011     1  Not Holiday   Saturday
# 1       2  2011-01-02  springer  2011     1  Not Holiday     Sunday
# 2       3  2011-01-03  springer  2011     1  Not Holiday     Monday
# 3       4  2011-01-04  springer  2011     1  Not Holiday    Tuesday
# 4       5  2011-01-05  springer  2011     1  Not Holiday  Wednesday
#
#   workingday weather  casual  registered  total
# 0     Offday       2     331         654    985
# 1     Offday       2     131         670    801
# 2    Workday       1     120        1229   1349
# ...

# %% [markdown]
# * Melakukan transformasi nilai pada kolom *weather* guna memastikan kesesuaiannya dengan konteks data yang dianalisis, sehingga lebih merepresentasikan kondisi cuaca secara lebih akurat dan sesuai dengan standar yang diterapkan dalam penelitian ini.

# %%
day_df['weather'] = day_df['weather'].replace({
    1:'Clear & Partly Cloudy',
    2:'Mist & Cloudy',
    3:'Light Snow & Light Rain',
    4:'Heavy rain & Ice Pallets'
})

day_df.head()
# Out:
# <ipython-input-19-baa6bcc350e6>:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   day_df['weather'] = day_df['weather'].replace({
#    rec_id     dateday    season  year month      holiday    weekday  \
# 0       1  2011-01-01  springer  2011     1  Not Holiday   Saturday
# 1       2  2011-01-02  springer  2011     1  Not Holiday     Sunday
# 2       3  2011-01-03  springer  2011     1  Not Holiday     Monday
# 3       4  2011-01-04  springer  2011     1  Not Holiday    Tuesday
# 4       5  2011-01-05  springer  2011     1  Not Holiday  Wednesday
#
#   workingday                weather  casual  registered  total
# 0     Offday          Mist & Cloudy     331         654    985
# 1     Offday          Mist & Cloudy     131         670    801
# ...

# %% [markdown]
# * Kolom *dateday* akan dikonversi ke dalam format *datetime* agar dapat digunakan dengan lebih optimal dalam operasi yang melibatkan manipulasi atau analisis data berdasarkan waktu.

# %%
day_df['dateday'] = day_df['dateday'].astype('datetime64[ns]')

day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rec_id      731 non-null    int64
#  1   dateday     731 non-null    datetime64[ns]
#  2   season      731 non-null    category
#  3   year        731 non-null    category
#  4   month       731 non-null    category
#  5   holiday     731 non-null    category
#  6   weekday     731 non-null    category
#  7   workingday  731 non-null    category
#  8   weather     731 non-null    category
#  9   casual      731 non-null    int64
#  10  registered  731 non-null    int64
#  11  total       731 non-null    int64
# dtypes: category(7), datetime64[ns](1), int64(4)
# memory usage: 35.1 KB

# %% [markdown]
# ### Cleaning hour_df data

# %%
hour_df.drop(columns=['temp', 'atemp', 'hum', 'windspeed'], inplace=True)

hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  casual  registered  cnt
# 0           1       3          13   16
# 1           1       8          32   40
# 2           1       5          27   32
# 3           1       3          10   13
# 4           1       0           1    1

# %%
hour_df.rename(columns={'instant':'rec_id', 'dteday':'dateday', 'yr':'year', 'mnth':'month', 'hr':'hour', 'weathersit':'weather', 'cnt':'total'}, inplace=True)

hour_df.head()
# Out:
#    rec_id     dateday  season  year  month  hour  holiday  weekday  \
# 0       1  2011-01-01       1     0      1     0        0        6
# 1       2  2011-01-01       1     0      1     1        0        6
# 2       3  2011-01-01       1     0      1     2        0        6
# 3       4  2011-01-01       1     0      1     3        0        6
# 4       5  2011-01-01       1     0      1     4        0        6
#
#    workingday  weather  casual  registered  total
# 0           0        1       3          13     16
# 1           0        1       8          32     40
# 2           0        1       5          27     32
# 3           0        1       3          10     13
# 4           0        1       0           1      1

# %%
for col2 in ['season', 'year', 'month', 'hour', 'holiday', 'weekday', 'workingday', 'weather']:
    hour_df[col2] = hour_df[col2].astype('category')

hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rec_id      17379 non-null  int64
#  1   dateday     17379 non-null  object
#  2   season      17379 non-null  category
#  3   year        17379 non-null  category
#  4   month       17379 non-null  category
#  5   hour        17379 non-null  category
#  6   holiday     17379 non-null  category
#  7   weekday     17379 non-null  category
#  8   workingday  17379 non-null  category
#  9   weather     17379 non-null  category
#  10  casual      17379 non-null  int64
#  11  registered  17379 non-null  int64
#  12  total       17379 non-null  int64
# dtypes: category(8), int64(4), object(1)
# memory usage: 817.0+ KB

# %%
hour_df['season'] = hour_df['season'].replace({
    1:'springer',
    2:'summer',
    3:'fall',
    4:'winter'
})

hour_df.head()
# Out:
# <ipython-input-24-9cfd0e375f7e>:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   hour_df['season'] = hour_df['season'].replace({
#    rec_id     dateday    season year month hour holiday weekday workingday  \
# 0       1  2011-01-01  springer    0     1    0       0       6          0
# 1       2  2011-01-01  springer    0     1    1       0       6          0
# 2       3  2011-01-01  springer    0     1    2       0       6          0
# 3       4  2011-01-01  springer    0     1    3       0       6          0
# 4       5  2011-01-01  springer    0     1    4       0       6          0
#
#   weather  casual  registered  total
# 0       1       3          13     16
# 1       1       8          32     40
# 2       1       5          27     32
# ...

# %%
hour_df['year'] = hour_df['year'].replace({
    0:2011,
    1:2012
})

hour_df.head()
# Out:
# <ipython-input-25-1d43e7459c09>:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   hour_df['year'] = hour_df['year'].replace({
#    rec_id     dateday    season  year month hour holiday weekday workingday  \
# 0       1  2011-01-01  springer  2011     1    0       0       6          0
# 1       2  2011-01-01  springer  2011     1    1       0       6          0
# 2       3  2011-01-01  springer  2011     1    2       0       6          0
# 3       4  2011-01-01  springer  2011     1    3       0       6          0
# 4       5  2011-01-01  springer  2011     1    4       0       6          0
#
#   weather  casual  registered  total
# 0       1       3          13     16
# 1       1       8          32     40
# 2       1       5          27     32
# ...

# %%
hour_df['hour'] = hour_df['hour'].replace({
    0:'12 am',
    1:'01 am',
    2:'02 am',
    3:'03 am',
    4:'04 am',
    5:'05 am',
    6:'06 am',
    7:'07 am',
    8:'08 am',
    9:'09 am',
    10:'10 am',
    11:'11 am',
    12:'12 pm',
    13:'01 pm',
    14:'02 pm',
    15:'03 pm',
    16:'04 pm',
    17:'05 pm',
    18:'06 pm',
    19:'07 pm',
    20:'08 pm',
    21:'09 pm',
    22:'10 pm',
    23:'11 pm',
})

hour_df.head()
# Out:
# <ipython-input-26-11ce7bae17be>:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   hour_df['hour'] = hour_df['hour'].replace({
#    rec_id     dateday    season  year month   hour holiday weekday workingday  \
# 0       1  2011-01-01  springer  2011     1  12 am       0       6          0
# 1       2  2011-01-01  springer  2011     1  01 am       0       6          0
# 2       3  2011-01-01  springer  2011     1  02 am       0       6          0
# 3       4  2011-01-01  springer  2011     1  03 am       0       6          0
# 4       5  2011-01-01  springer  2011     1  04 am       0       6          0
#
#   weather  casual  registered  total
# 0       1       3          13     16
# 1       1       8          32     40
# 2       1       5          27     32
# ...

# %%
hour_df['holiday'] = hour_df['holiday'].replace({
    0:'Not Holiday',
    1:'Holiday'
})

hour_df.head()
# Out:
# <ipython-input-27-ec7ca02b46e9>:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   hour_df['holiday'] = hour_df['holiday'].replace({
#    rec_id     dateday    season  year month   hour      holiday weekday  \
# 0       1  2011-01-01  springer  2011     1  12 am  Not Holiday       6
# 1       2  2011-01-01  springer  2011     1  01 am  Not Holiday       6
# 2       3  2011-01-01  springer  2011     1  02 am  Not Holiday       6
# 3       4  2011-01-01  springer  2011     1  03 am  Not Holiday       6
# 4       5  2011-01-01  springer  2011     1  04 am  Not Holiday       6
#
#   workingday weather  casual  registered  total
# 0          0       1       3          13     16
# 1          0       1       8          32     40
# 2          0       1       5          27     32
# ...

# %%
hour_df['weekday'] = hour_df['weekday'].replace({
    0:'Sunday',
    1:'Monday',
    2:'Tuesday',
    3:'Wednesday',
    4:'Thursday',
    5:'Friday',
    6:'Saturday'
})

hour_df.head()
# Out:
# <ipython-input-28-7e7b7f5dfcd2>:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   hour_df['weekday'] = hour_df['weekday'].replace({
#    rec_id     dateday    season  year month   hour      holiday   weekday  \
# 0       1  2011-01-01  springer  2011     1  12 am  Not Holiday  Saturday
# 1       2  2011-01-01  springer  2011     1  01 am  Not Holiday  Saturday
# 2       3  2011-01-01  springer  2011     1  02 am  Not Holiday  Saturday
# 3       4  2011-01-01  springer  2011     1  03 am  Not Holiday  Saturday
# 4       5  2011-01-01  springer  2011     1  04 am  Not Holiday  Saturday
#
#   workingday weather  casual  registered  total
# 0          0       1       3          13     16
# 1          0       1       8          32     40
# ...

# %%
hour_df['workingday'] = hour_df['workingday'].replace({
    0:'Offday',
    1:'Workday'
})

hour_df.head()
# Out:
# <ipython-input-29-bb9825b8f9a7>:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   hour_df['workingday'] = hour_df['workingday'].replace({
#    rec_id     dateday    season  year month   hour      holiday   weekday  \
# 0       1  2011-01-01  springer  2011     1  12 am  Not Holiday  Saturday
# 1       2  2011-01-01  springer  2011     1  01 am  Not Holiday  Saturday
# 2       3  2011-01-01  springer  2011     1  02 am  Not Holiday  Saturday
# 3       4  2011-01-01  springer  2011     1  03 am  Not Holiday  Saturday
# 4       5  2011-01-01  springer  2011     1  04 am  Not Holiday  Saturday
#
#   workingday weather  casual  registered  total
# 0     Offday       1       3          13     16
# 1     Offday       1       8          32     40
# ...

# %%
hour_df['weather'] = hour_df['weather'].replace({
    1:'Clear & Partly Cloudy',
    2:'Mist & Cloudy',
    3:'Light Snow & Light Rain',
    4:'Heavy rain & Ice Pallets'
})

hour_df.head()
# Out:
# <ipython-input-30-145e54e55efd>:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   hour_df['weather'] = hour_df['weather'].replace({
#    rec_id     dateday    season  year month   hour      holiday   weekday  \
# 0       1  2011-01-01  springer  2011     1  12 am  Not Holiday  Saturday
# 1       2  2011-01-01  springer  2011     1  01 am  Not Holiday  Saturday
# 2       3  2011-01-01  springer  2011     1  02 am  Not Holiday  Saturday
# 3       4  2011-01-01  springer  2011     1  03 am  Not Holiday  Saturday
# 4       5  2011-01-01  springer  2011     1  04 am  Not Holiday  Saturday
#
#   workingday                weather  casual  registered  total
# 0     Offday  Clear & Partly Cloudy       3          13     16
# ...

# %%
hour_df['dateday'] = hour_df['dateday'].astype('datetime64[ns]')

hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rec_id      17379 non-null  int64
#  1   dateday     17379 non-null  datetime64[ns]
#  2   season      17379 non-null  category
#  3   year        17379 non-null  category
#  4   month       17379 non-null  category
#  5   hour        17379 non-null  category
#  6   holiday     17379 non-null  category
#  7   weekday     17379 non-null  category
#  8   workingday  17379 non-null  category
#  9   weather     17379 non-null  category
#  10  casual      17379 non-null  int64
#  11  registered  17379 non-null  int64
#  12  total       17379 non-null  int64
# dtypes: category(8), datetime64[ns](1), int64(4)
# memory usage: 817.0 KB

# %% [markdown]
# ## Exploratory Data Analysis (EDA).
#
# Dalam proses *Exploratory Data Analysis* (EDA), hanya akan menggunakan *dataframe* `hour_df` sebagai objek analisis utama. Keputusan ini didasarkan pada fakta bahwa `hour_df` memiliki atribut yang lebih lengkap dibandingkan dengan alternatifnya. Selain itu, kedua *dataframe* yang tersedia dalam penelitian ini memberikan nilai yang identik untuk atribut yang sama, sehingga penggunaan `hour_df` dianggap lebih efisien dan representatif dalam memperoleh wawasan dari data yang dianalisis.

# %%
hour_df.describe(include='all')
# Out:
#             rec_id                        dateday season     year    month  \
# count   17379.0000                          17379  17379  17379.0  17379.0
# unique         NaN                            NaN      4      2.0     12.0
# top            NaN                            NaN   fall   2012.0      5.0
# freq           NaN                            NaN   4496   8734.0   1488.0
# mean     8690.0000  2012-01-02 04:08:34.552045568    NaN      NaN      NaN
# min         1.0000            2011-01-01 00:00:00    NaN      NaN      NaN
# 25%      4345.5000            2011-07-04 00:00:00    NaN      NaN      NaN
# 50%      8690.0000            2012-01-02 00:00:00    NaN      NaN      NaN
# 75%     13034.5000            2012-07-02 00:00:00    NaN      NaN      NaN
# max     17379.0000            2012-12-31 00:00:00    NaN      NaN      NaN
# std      5017.0295                            NaN    NaN      NaN      NaN
#
# ...

# %% [markdown]
# Dapat diamati bahwa jumlah rata-rata pengguna yang telah terdaftar sebagai pengguna resmi atau *registered users* cenderung lebih tinggi dibandingkan dengan jumlah rata-rata pengguna yang tidak terdaftar atau *casual users*. Hal ini menunjukkan adanya kecenderungan bahwa sebagian besar individu yang memanfaatkan layanan tersebut lebih memilih untuk melakukan registrasi dibandingkan dengan menggunakan layanan secara sementara tanpa proses pendaftaran.

# %% [markdown]
# ### Comparing Registered, Casual, and Total Consumers by Different Categories.

# %% [markdown]
# Berlandaskan pada periode musiman :

# %%
sea_hour_df = hour_df.groupby(by='season').agg({
    'registered':'sum',
    'casual':'sum',
    'total':'sum'
}).sort_values(by='total', ascending=False)

sea_hour_df
# Out:
# <ipython-input-33-b67b9b26746d>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sea_hour_df = hour_df.groupby(by='season').agg({
#           registered  casual    total
# season
# fall          835038  226091  1061129
# summer        715067  203522   918589
# winter        711831  129782   841613
# springer      410726   60622   471348

# %% [markdown]
# Berlandaskan pada periode tahunan :

# %%
hour_df.groupby(by='year').agg({
    'registered':'sum',
    'casual':'sum',
    'total':'sum'
}).sort_values(by='total', ascending=False)
# Out:
# <ipython-input-34-03d474231fde>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   hour_df.groupby(by='year').agg({
#       registered  casual    total
# year
# 2012     1676811  372765  2049576
# 2011      995851  247252  1243103

# %% [markdown]
# Berlandaskan pada periode bulanan :

# %%
hour_df.groupby(by='month').agg({
    'registered':'sum',
    'casual':'sum',
    'total':'sum'
}).sort_values(by='total', ascending=False)
# Out:
# <ipython-input-35-932b1f83b057>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   hour_df.groupby(by='month').agg({
#        registered  casual   total
# month
# 8          279155   72039  351194
# 6          272436   73906  346342
# 9          275668   70323  345991
# 7          266791   78157  344948
# 5          256401   75285  331686
# 10         262592   59760  322352
# 4          208292   60802  269094
# 11         218228   36603  254831
# 3          184476   44444  228920
# 12         189343   21693  211036
# 2          136389   14963  151352
# 1          122891   12042  134933

# %% [markdown]
# Berlandasan pada periode jam :

# %%
hr_hour_df = hour_df.groupby(by=['hour']).agg({
    'registered':'sum',
    'casual':'sum',
    'total':'sum'
}).sort_values(by='total', ascending=False)

hr_hour_df
# Out:
# <ipython-input-36-e2e10c53d988>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   hr_hour_df = hour_df.groupby(by=['hour']).agg({
#        registered  casual   total
# hour
# 05 pm      282640   54220  336860
# 06 pm      265276   44496  309772
# 08 am      245240   15761  261001
# 04 pm      173914   53834  227748
# 07 pm      191284   35505  226789
# 01 pm      132206   52713  184919
# 12 pm      134696   49718  184414
# 03 pm      128543   54606  183149
# 02 pm      120563   55089  175652
# 08 pm      138172   26378  164550
# 09 am      136980   22458  159438
# 07 am      146134    8037  154171
# 11 am      108034   43286  151320
# 10 am       92468   33789  126257
# 09 pm      104875   20570  125445
# 10 pm       79412   16200   95612
# 11 pm       52876   11065   63941
# ...

# %% [markdown]
# Berdasarkan pada periode liburan :

# %%
hour_df.groupby(by='holiday').agg({
    'registered':'sum',
    'casual':'sum',
    'total':'sum'
}).sort_values(by='total', ascending=False)
# Out:
# <ipython-input-37-8b902ac710f7>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   hour_df.groupby(by='holiday').agg({
#              registered  casual    total
# holiday
# Not Holiday     2616586  597658  3214244
# Holiday           56076   22359    78435

# %% [markdown]
# Berdasarkan pada periode weekday :

# %%
hour_df.groupby(by='weekday').agg({
    'registered':'sum',
    'casual':'sum',
    'total':'sum'
}).sort_values(by='total', ascending=False)
# Out:
# <ipython-input-38-4fab6d0fe9f0>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   hour_df.groupby(by='weekday').agg({
#            registered  casual   total
# weekday
# Friday         409552   78238  487790
# Thursday       423935   61460  485395
# Saturday       323955  153852  477807
# Wednesday      415729   57319  473048
# Tuesday        411266   57843  469109
# Monday         384719   70784  455503
# Sunday         303506  140521  444027

# %% [markdown]
# Berdasarkan pada periode workday :

# %%
wd_hour_df = hour_df.groupby(by='workingday').agg({
    'registered':'sum',
    'casual':'sum',
    'total':'sum'
}).sort_values(by='total', ascending=False)

wd_hour_df
# Out:
# <ipython-input-39-2ffd8e8d8c81>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   wd_hour_df = hour_df.groupby(by='workingday').agg({
#             registered  casual    total
# workingday
# Workday        1989125  303285  2292410
# Offday          683537  316732  1000269

# %% [markdown]
# Berdasarkan pada periode musiman :

# %%
weat_hour_df = hour_df.groupby(by='weather').agg({
    'registered':'sum',
    'casual':'sum',
    'total':'sum'
}).sort_values(by='total', ascending=False)

weat_hour_df
# Out:
# <ipython-input-40-ac3f879ac16b>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   weat_hour_df = hour_df.groupby(by='weather').agg({
#                           registered  casual    total
# weather
# Clear & Partly Cloudy        1875428  462745  2338173
# Mist & Cloudy                 661471  134481   795952
# Light Snow & Light Rain       135548   22783   158331
# Heavy rain & Ice Pallets         215       8      223

# %% [markdown]
# **Insight:**
# > * Berdasarkan hasil analisis terhadap data penggunaan layanan Bike Sharing, terdapat tren peningkatan jumlah pengguna secara signifikan dari tahun 2011 hingga tahun 2012. Kenaikan ini dapat mengindikasikan bahwa layanan Bike Sharing semakin diminati oleh masyarakat, baik untuk kebutuhan transportasi harian maupun aktivitas rekreasi. Peningkatan ini juga dapat menunjukkan adanya kesadaran yang lebih besar terhadap manfaat penggunaan sepeda sebagai alternatif moda transportasi yang lebih ramah lingkungan.
#
# > * Jika ditinjau berdasarkan musim, musim gugur (Fall) merupakan periode dengan tingkat penggunaan Bike Sharing yang paling tinggi dibandingkan dengan musim lainnya. Hal ini dapat disebabkan oleh kondisi cuaca yang lebih bersahabat, di mana suhu udara tidak terlalu panas seperti pada musim panas maupun terlalu dingin seperti pada musim dingin, sehingga lebih nyaman bagi pengguna untuk bersepeda. Sebaliknya, musim semi (Spring) tercatat sebagai musim dengan jumlah pengguna Bike Sharing paling sedikit. Faktor-faktor yang dapat mempengaruhi rendahnya penggunaan pada musim semi mungkin termasuk kondisi cuaca yang masih tidak stabil, dengan kemungkinan curah hujan yang cukup tinggi, serta suhu yang belum sepenuhnya hangat, sehingga mengurangi minat masyarakat untuk menggunakan layanan ini.
#
# > * Analisis terhadap pola penggunaan berdasarkan bulan dalam satu tahun menunjukkan bahwa bulan ke-8, yang bertepatan dengan bulan Agustus, merupakan periode dengan jumlah pengguna Bike Sharing tertinggi. Salah satu faktor yang mungkin berkontribusi terhadap tingginya angka penggunaan pada bulan ini adalah adanya liburan musim panas atau periode libur sekolah di beberapa negara, yang memungkinkan masyarakat untuk lebih sering beraktivitas di luar ruangan, termasuk menggunakan sepeda sebagai sarana transportasi atau rekreasi. Sebaliknya, bulan pertama dalam satu tahun, yaitu bulan Januari, memiliki jumlah pengguna Bike Sharing yang paling sedikit. Hal ini dapat dikaitkan dengan kondisi cuaca yang lebih dingin di banyak wilayah, terutama di belahan bumi utara, yang cenderung mengurangi kenyamanan dalam bersepeda, serta adanya awal tahun yang umumnya diwarnai dengan penyesuaian kembali terhadap rutinitas setelah liburan panjang.
#
# > * Berdasarkan pola penggunaan harian, terdapat kecenderungan yang cukup jelas bahwa jumlah pengguna Bike Sharing jauh lebih tinggi pada hari kerja dibandingkan dengan hari libur. Hal ini menunjukkan bahwa layanan Bike Sharing banyak dimanfaatkan sebagai sarana transportasi utama untuk aktivitas yang bersifat rutin, seperti perjalanan menuju tempat kerja atau institusi pendidikan. Sebaliknya, pada hari libur, jumlah pengguna cenderung lebih rendah, yang mungkin disebabkan oleh berkurangnya mobilitas masyarakat untuk kegiatan rutin serta lebih banyaknya pilihan moda transportasi lain yang dapat digunakan untuk rekreasi atau perjalanan santai.
#
# > * Jika dianalisis lebih spesifik berdasarkan hari dalam satu minggu, hari Jumat tercatat sebagai hari dengan jumlah pengguna Bike Sharing tertinggi. Fenomena ini dapat dikaitkan dengan tingginya aktivitas masyarakat pada akhir pekan, di mana banyak individu masih bekerja namun juga mulai merencanakan aktivitas tambahan setelah jam kerja, sehingga meningkatkan permintaan terhadap layanan sepeda. Sebaliknya, hari Minggu merupakan hari dengan jumlah pengguna Bike Sharing paling rendah. Kemungkinan besar, hal ini terjadi karena pada hari Minggu, banyak orang memilih untuk beristirahat di rumah atau menggunakan moda transportasi lain yang lebih nyaman untuk perjalanan bersama keluarga, sehingga permintaan terhadap Bike Sharing menjadi lebih rendah dibandingkan hari-hari lainnya.
#
# > * Pola penggunaan Bike Sharing juga memperlihatkan perbedaan yang signifikan berdasarkan waktu dalam satu hari. Pukul 17.00 (5 PM) tercatat sebagai jam dengan tingkat penggunaan tertinggi. Hal ini sangat mungkin terjadi karena waktu tersebut bertepatan dengan jam pulang kerja atau pulang sekolah, di mana banyak individu membutuhkan sarana transportasi untuk kembali ke rumah setelah beraktivitas sepanjang hari. Selain itu, pada jam tersebut, kondisi cuaca umumnya lebih nyaman dibandingkan siang hari, sehingga memungkinkan lebih banyak orang untuk memilih bersepeda. Sebaliknya, pukul 04.00 (4 AM) merupakan waktu dengan jumlah pengguna paling sedikit. Fenomena ini dapat dipahami mengingat bahwa jam tersebut masih termasuk waktu dini hari, ketika mobilitas masyarakat sangat rendah, serta masih minimnya kebutuhan transportasi pada saat itu.
#
# > * Selain faktor waktu dan hari, kondisi cuaca juga berperan besar dalam menentukan jumlah pengguna layanan Bike Sharing. Data menunjukkan bahwa ketika cuaca cerah atau dalam kondisi baik, jumlah pengguna Bike Sharing meningkat secara signifikan. Hal ini dapat terjadi karena bersepeda menjadi lebih nyaman dan aman saat cuaca mendukung. Sebaliknya, dalam kondisi cuaca buruk, seperti hujan deras, penggunaan Bike Sharing mengalami penurunan yang cukup drastis. Faktor keamanan dan kenyamanan menjadi pertimbangan utama bagi pengguna untuk menghindari bersepeda dalam kondisi hujan deras, mengingat risiko kecelakaan dan ketidaknyamanan saat bersepeda di bawah hujan dapat meningkat secara signifikan.
#
# > * Selain analisis berdasarkan faktor eksternal seperti waktu, musim, dan cuaca, perbandingan jumlah pengguna juga dapat ditinjau berdasarkan kategori pengguna. Data menunjukkan bahwa jumlah pengguna terdaftar atau registered users secara konsisten lebih tinggi dibandingkan dengan pengguna kasual atau casual users. Hal ini mengindikasikan bahwa mayoritas pengguna Bike Sharing adalah individu yang telah berlangganan layanan ini dan menggunakannya secara rutin, baik untuk keperluan transportasi sehari-hari maupun sebagai bagian dari gaya hidup aktif. Sementara itu, pengguna kasual cenderung menggunakan layanan ini hanya pada kesempatan tertentu, seperti untuk rekreasi atau ketika ada kebutuhan transportasi mendadak. Perbedaan ini dapat menjadi indikasi bahwa Bike Sharing telah menjadi pilihan utama bagi banyak pengguna yang mencari alternatif transportasi yang efisien dan berkelanjutan.

# %% [markdown]
# ## Visualization & Explanatory Analysis
#
#
# 1. Bagaimana perbedaan antara pengguna yang menggunakan layanan bike sharing secara kasual tanpa registrasi dengan mereka yang telah mendaftar sebagai anggota tetap dalam sistem tersebut?

# %% [markdown]
# Berikut ini adalah Analisis Perbedaan Antara Pengguna Bike Sharing yang Bersifat Kasual dengan Pengguna yang Telah Terdaftar dalam Sistem:

# %%
import matplotlib.pyplot as plt

# Data
casreg_pie = hour_df[['casual', 'registered']].sum()

# Warna untuk pie chart
colors = ['#800020', '#F5F5DC']  # Burgundy & Beige

# Buat pie chart
plt.figure(figsize=(5, 5))
wedges, texts, autotexts = plt.pie(
    casreg_pie.values, labels=casreg_pie.index, autopct='%1.1f%%', colors=colors,
    startangle=90, wedgeprops={'edgecolor': 'black'}
)

# Atur warna teks persentase
autotexts[0].set_color('#F5F5DC')  # Casual → Beige
autotexts[1].set_color('#800020')  # Registered → Burgundy

# Atur warna label (User Type)
for text in texts:
    text.set_color("black")

# Tambahkan judul
plt.title("Casual vs Registered Users", fontsize=12, fontweight='bold', color="#800020")

# Tampilkan plot
plt.show()

# %% [markdown]
# 2. Pada jam berapa dalam sehari tingkat penggunaan layanan bike sharing mencapai puncak tertinggi, dan pada jam berapa penggunaan tersebut berada pada titik terendah?

# %% [markdown]
# Berikut adalah Periode waktu atau jam tertentu ketika penggunaan layanan berbagi sepeda mencapai tingkat tertinggi dan terendah:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Setup figure
f, ax = plt.subplots(figsize=(17, 5))
sns.despine(f)
sns.set_style('whitegrid')

# Plot line chart
sns.lineplot(data=hr_hour_df, x='hour', y='total', color='#800020', linewidth=2, marker='o', markerfacecolor='#F5F5DC', markeredgecolor='black')

# Styling
plt.title('Penggunaan Bike Sharing Tertinggi dan Terendah Berdasarkan Waktu (Jam)', fontsize=12, fontweight='bold', color="#800020")
plt.xlabel(None)
plt.ylabel(None)

plt.show()

# %% [markdown]
# 3. Bagaimana perbedaan dalam pola penggunaan layanan bike sharing ketika dihadapkan pada empat kondisi cuaca yang berbeda, dan sejauh mana faktor cuaca memengaruhi tingkat penggunaannya?

# %% [markdown]
# Berikut adalah analisis perbandingan mengenai tingkat pemanfaatan layanan Bike Sharing dalam berbagai kondisi cuaca, mencakup empat jenis cuaca yang berbeda:

# %%
f, ax = plt.subplots(figsize=(10, 5))

sns.despine(f)
sns.set_style('whitegrid')

custom_palette = ["#800020", "#A52A2A", "#F5F5DC", "#D2B48C"]

sns.barplot(data=weat_hour_df, x='weather', y='total', hue='weather', palette=custom_palette,
            edgecolor="black", legend=False)

plt.title("Perbandingan Penggunaan Bike Sharing Pada 4 Tipe Cuaca yang Berbeda", fontsize=14, fontweight='bold', color="#800020")

plt.xlabel(None)
plt.ylabel(None)

plt.show()

# %%
hour_df.to_csv("main_data.csv", index=False)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# > ## Pertanyaan nomor 1 :
# Jumlah pengguna yang telah melakukan pendaftaran sebagai member atau pengguna terdaftar jauh lebih tinggi dibandingkan dengan jumlah pengguna yang hanya menggunakan layanan secara kasual tanpa registrasi. Persentase pengguna terdaftar mencapai 81.2%, sedangkan pengguna kasual hanya mencakup 18.8% dari total pengguna.
#
# > ## Pertanyaan nomor 2 :
# Pola penggunaan layanan Bike Sharing menunjukkan bahwa pada hari kerja, puncak aktivitas peminjaman sepeda terjadi pada pukul 17.00 atau jam 5 sore. Hal ini kemungkinan besar disebabkan oleh banyaknya pekerja yang pulang dari kantor pada jam tersebut. Sementara itu, pada hari non-kerja seperti akhir pekan atau hari libur, jumlah pengguna terbanyak justru tercatat pada pukul 13.00 atau jam 1 siang, yang mungkin bertepatan dengan waktu santai atau aktivitas rekreasi masyarakat.
#
# > ## Pertanyaan nomor 3 :
# Kondisi cuaca ternyata memiliki pengaruh signifikan terhadap jumlah pengguna Bike Sharing. Saat cuaca cerah, layanan ini digunakan oleh lebih banyak orang dibandingkan dengan kondisi cuaca lainnya. Sebaliknya, ketika terjadi hujan deras, jumlah pengguna menurun drastis, menjadikannya kondisi cuaca dengan tingkat penggunaan terendah.
